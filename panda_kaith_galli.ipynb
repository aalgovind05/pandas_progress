# %%
import pandas as pd
df = pd.DataFrame([[2,5,5,8,7],[5,4,8,7,9],[5,4,7,5,2]],columns = ["a","b","c","d","e"])

# %%
df = pd.DataFrame([[2,5,5,8,7],[5,4,8,7,9],[5,4,7,5,2]],columns = ["a","b","c","d","e"])

# %%
df.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='str')

# %%
gut = pd.read_csv(r"C:\Users\aalgo\Downloads\archive_(4)\Amazon_Sale_Report.csv")
# Out:
# C:\Users\aalgo\AppData\Local\Temp\ipykernel_29136\3729815047.py:1: DtypeWarning: Columns (0: Unnamed: 22) have mixed types. Specify dtype option on import or set low_memory=False.
#   gut = pd.read_csv(r"C:\Users\aalgo\Downloads\archive_(4)\Amazon_Sale_Report.csv")

# %%
gut.loc[gut['Amount'] > 700,['Category','currency','Amount']]
# Out:
#              Category currency   Amount
# 3       Western Dress      INR   753.33
# 5                 Set      INR   824.00
# 14                Set      INR   771.00
# 19                Set      INR   886.00
# 30      Western Dress      INR   791.00
# ...               ...      ...      ...
# 128964  Western Dress      INR   899.00
# 128966            Set      INR  1132.00
# 128968            Set      INR   824.00
# 128971            Set      INR   999.00
# 128973            Set      INR  1199.00
#
# [45261 rows x 3 columns]

# %%
gut[(gut['Amount'] > 700)]
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
# 5      5  404-1490984-4578765  04-30-22                       Shipped
# 6      6  408-5748499-6859555  04-30-22                       Shipped
# 7      7  406-7807733-3785945  04-30-22  Shipped - Delivered to Buyer
# 8      8  407-5443024-5233168  04-30-22                     Cancelled
# 9      9  402-4393761-0311520  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style                  SKU  \
# 0   Merchant      Amazon.in           Standard   SET389       SET389-KR-NP-S
# ...

# %%
gut[(gut['Amount'] > 700) & (gut['Category']=='Set')]
# Out:
#          index             Order ID      Date                        Status  \
# 5            5  404-1490984-4578765  04-30-22                       Shipped
# 14          14  408-1298370-1920302  04-30-22  Shipped - Delivered to Buyer
# 19          19  405-5957858-1051546  04-30-22                       Shipped
# 32          32  404-9632124-1107550  04-30-22  Shipped - Delivered to Buyer
# 43          43  408-3478480-0881162  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128957  128957  402-8261465-0622733  05-31-22                       Shipped
# 128966  128966  406-9812666-2474761  05-31-22                       Shipped
# 128968  128968  403-7059995-7618722  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
#
# ...

# %%
gut[gut['Category'].str.contains("set",case = False)]
# Out:
#          index             Order ID      Date     Status Fulfilment  \
# 0            0  405-8078784-5731545  04-30-22  Cancelled   Merchant
# 5            5  404-1490984-4578765  04-30-22    Shipped     Amazon
# 6            6  408-5748499-6859555  04-30-22    Shipped     Amazon
# 8            8  407-5443024-5233168  04-30-22  Cancelled     Amazon
# 13          13  408-7955685-3083534  04-30-22    Shipped     Amazon
# ...        ...                  ...       ...        ...        ...
# 128968  128968  403-7059995-7618722  05-31-22    Shipped     Amazon
# 128969  128969  404-3802633-7250760  05-31-22  Cancelled     Amazon
# 128971  128971  402-9551604-7544318  05-31-22    Shipped     Amazon
# 128973  128973  402-6184140-0545956  05-31-22    Shipped     Amazon
# 128974  128974  408-7436540-8728312  05-31-22    Shipped     Amazon
#
#        Sales Channel  ship-service-level   Style                  SKU  \
# 0           Amazon.in           Standard  SET389       SET389-KR-NP-S
# ...

# %%
gut[gut['Category'].str.contains("top",case=False)]
# Out:
#          index             Order ID      Date                        Status  \
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# 47          47  408-9281152-6213100  04-30-22                       Shipped
# 54          54  402-7944191-1869101  04-30-22                       Shipped
# 67          67  404-4535078-5241919  04-30-22                       Shipped
# 109        109  403-7266170-1163500  04-30-22  Shipped - Delivered to Buyer
# ...        ...                  ...       ...                           ...
# 128923  128923  402-1698543-5164342  05-31-22                       Shipped
# 128941  128941  403-3035549-4142738  05-31-22                       Shipped
# 128942  128942  403-3035549-4142738  05-31-22                       Shipped
# 128949  128949  403-7050981-8813953  05-31-22                       Shipped
# 128965  128965  408-5154281-4593912  05-31-22                     Cancelled
#
# ...

# %%
gut['Category'].unique
# Out:
# <bound method Series.unique of 0                   Set
# 1                 kurta
# 2                 kurta
# 3         Western Dress
# 4                   Top
#               ...
# 128970            kurta
# 128971              Set
# 128972    Western Dress
# 128973              Set
# 128974              Set
# Name: Category, Length: 128975, dtype: str>

# %%
gut[gut['ship-state'].str.contains("GUJARAT",case = False,na =False)]
# Out:
#          index             Order ID      Date     Status Fulfilment  \
# 65          65  171-4137548-0481151  04-30-22  Cancelled     Amazon
# 78          78  403-6190683-2687538  04-30-22    Shipped     Amazon
# 89          89  171-6833843-5473114  04-30-22    Shipped     Amazon
# 93          93  406-5727754-5302723  04-30-22    Shipped     Amazon
# 94          94  405-0901744-8270705  04-30-22    Shipped     Amazon
# ...        ...                  ...       ...        ...        ...
# 128838  128838  402-3140751-2277925  06-01-22    Shipped     Amazon
# 128858  128858  403-3993144-2397937  06-01-22    Shipped     Amazon
# 128935  128935  408-3874942-4863549  05-31-22    Shipped     Amazon
# 128961  128961  402-0082204-6323568  05-31-22  Cancelled     Amazon
# 128973  128973  402-6184140-0545956  05-31-22    Shipped     Amazon
#
#        Sales Channel  ship-service-level    Style              SKU  \
# 65          Amazon.in          Expedited  JNE3373   JNE3373-KR-XXL
# ...

# %%
gut[(gut['ship-state']=="Gujarat")]
# Out:
#          index             Order ID      Date     Status Fulfilment  \
# 65          65  171-4137548-0481151  04-30-22  Cancelled     Amazon
# 78          78  403-6190683-2687538  04-30-22    Shipped     Amazon
# 89          89  171-6833843-5473114  04-30-22    Shipped     Amazon
# 93          93  406-5727754-5302723  04-30-22    Shipped     Amazon
# 94          94  405-0901744-8270705  04-30-22    Shipped     Amazon
# ...        ...                  ...       ...        ...        ...
# 128838  128838  402-3140751-2277925  06-01-22    Shipped     Amazon
# 128858  128858  403-3993144-2397937  06-01-22    Shipped     Amazon
# 128935  128935  408-3874942-4863549  05-31-22    Shipped     Amazon
# 128961  128961  402-0082204-6323568  05-31-22  Cancelled     Amazon
# 128973  128973  402-6184140-0545956  05-31-22    Shipped     Amazon
#
#        Sales Channel  ship-service-level    Style              SKU  \
# 65          Amazon.in          Expedited  JNE3373   JNE3373-KR-XXL
# ...

# %%
gut[gut['Order ID'].str.startswith(107)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 gut[gut['Order ID'].str.startswith(107)]
#
# File c:\Users\aalgo\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\strings\accessor.py:142, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     137     msg = (
#     138         f"Cannot use .str.{func_name} with values of "
#     139         f"inferred dtype '{self._inferred_dtype}'."
#     140     )
#     141     raise TypeError(msg)
# --> 142 return func(self, *args, **kwargs)
#
# File c:\Users\aalgo\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\strings\accessor.py:3172, in StringMethods.startswith(self, pat, na)
#    3170 if not isinstance(pat, (str, tuple)):
#    3171     msg = f"expected a string or tuple, not {type(pat).__name__}"
# ...

# %%
gut[gut['Category'].str.startswith("Top")]
# Out:
#          index             Order ID      Date                        Status  \
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# 47          47  408-9281152-6213100  04-30-22                       Shipped
# 54          54  402-7944191-1869101  04-30-22                       Shipped
# 67          67  404-4535078-5241919  04-30-22                       Shipped
# 109        109  403-7266170-1163500  04-30-22  Shipped - Delivered to Buyer
# ...        ...                  ...       ...                           ...
# 128923  128923  402-1698543-5164342  05-31-22                       Shipped
# 128941  128941  403-3035549-4142738  05-31-22                       Shipped
# 128942  128942  403-3035549-4142738  05-31-22                       Shipped
# 128949  128949  403-7050981-8813953  05-31-22                       Shipped
# 128965  128965  408-5154281-4593912  05-31-22                     Cancelled
#
# ...
