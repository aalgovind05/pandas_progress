# %%
import pandas as pd
import numpy as nb
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\aalgo\Downloads\archive_(4)\Amazon_Sale_Report.csv")
# Out:
# C:\Users\aalgo\AppData\Local\Temp\ipykernel_27056\742653858.py:1: DtypeWarning: Columns (0: Unnamed: 22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\aalgo\Downloads\archive_(4)\Amazon_Sale_Report.csv")

# %%
df.shape
# Out:
# (128975, 24)

# %%
df.set_index("index", inplace=True)

# %%
df.tail()
# Out:
#                    Order ID      Date   Status Fulfilment Sales Channel   \
# index
# 128970  406-6001380-7673107  05-31-22  Shipped     Amazon      Amazon.in
# 128971  402-9551604-7544318  05-31-22  Shipped     Amazon      Amazon.in
# 128972  407-9547469-3152358  05-31-22  Shipped     Amazon      Amazon.in
# 128973  402-6184140-0545956  05-31-22  Shipped     Amazon      Amazon.in
# 128974  408-7436540-8728312  05-31-22  Shipped     Amazon      Amazon.in
#
#        ship-service-level    Style             SKU       Category Size  ...  \
# index                                                                   ...
# 128970          Expedited  JNE3697   JNE3697-KR-XL          kurta   XL  ...
# 128971          Expedited   SET401  SET401-KR-NP-M            Set    M  ...
# 128972          Expedited    J0157    J0157-DR-XXL  Western Dress  XXL  ...
# 128973          Expedited    J0012    J0012-SKD-XS            Set   XS  ...
# ...

# %%
df.describe()
# Out:
#                  Qty         Amount  ship-postal-code
# count  128975.000000  121180.000000     128942.000000
# mean        0.904431     648.561465     463966.236509
# std         0.313354     281.211687     191476.764941
# min         0.000000       0.000000     110001.000000
# 25%         1.000000     449.000000     382421.000000
# 50%         1.000000     605.000000     500033.000000
# 75%         1.000000     788.000000     600024.000000
# max        15.000000    5584.000000     989898.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 23 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            128975 non-null  str
#  1   Date                128975 non-null  str
#  2   Status              128975 non-null  str
#  3   Fulfilment          128975 non-null  str
#  4   Sales Channel       128975 non-null  str
#  5   ship-service-level  128975 non-null  str
#  6   Style               128975 non-null  str
#  7   SKU                 128975 non-null  str
#  8   Category            128975 non-null  str
#  9   Size                128975 non-null  str
#  10  ASIN                128975 non-null  str
#  11  Courier Status      122103 non-null  str
#  12  Qty                 128975 non-null  int64
#  13  currency            121180 non-null  str
#  14  Amount              121180 non-null  float64
#  15  ship-city           128942 non-null  str
# ...

# %% [markdown]
# **no need to do df.fillna or df.dropna here**

# %%
df.head()
# Out:
#                   Order ID      Date                        Status Fulfilment  \
# index
# 0      405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1      171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2      404-0687676-7273146  04-30-22                       Shipped     Amazon
# 3      403-9615377-8133951  04-30-22                     Cancelled   Merchant
# 4      407-1069790-7240320  04-30-22                       Shipped     Amazon
#
#       Sales Channel  ship-service-level    Style              SKU  \
# index
# 0          Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1          Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2          Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3          Amazon.in           Standard    J0341       J0341-DR-L
# 4          Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#             Category Size  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
df['ship-city'] = df['ship-city'].str.lower()

# %%
df['ship-city'] = df['ship-city'].str.upper()

# %%
df.loc[50]
# Out:
# Order ID                                       408-2137113-0982751
# Date                                                      04-30-22
# Status                                                     Shipped
# Fulfilment                                                  Amazon
# Sales Channel                                            Amazon.in
# ship-service-level                                       Expedited
# Style                                                        J0186
# SKU                                                    J0186-SET-S
# Category                                                       Set
# Size                                                             S
# ASIN                                                    B091Z81MLX
# Courier Status                                             Shipped
# Qty                                                              1
# currency                                                       INR
# ...

# %%
df
# Out:
#                    Order ID      Date                        Status  \
# index
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 4       407-1069790-7240320  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  408-7436540-8728312  05-31-22                       Shipped
#
#        Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# index
# ...

# %%
df
# Out:
#                    Order ID      Date                        Status  \
# index
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 4       407-1069790-7240320  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  408-7436540-8728312  05-31-22                       Shipped
#
#        Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# index
# ...

# %%
df.groupby('Category')['Amount'].sum()
# Out:
# Category
# Blouse             458408.18
# Bottom             150667.98
# Dupatta               915.00
# Ethnic Dress       791217.66
# Saree              123933.76
# Set              39204124.03
# Top               5347792.30
# Western Dress    11216072.69
# kurta            21299546.70
# Name: Amount, dtype: float64

# %%
df.sample(5)
# Out:
#                   Order ID      Date                        Status Fulfilment  \
# index
# 43827  403-0499978-2057911  04-04-22  Shipped - Delivered to Buyer   Merchant
# 98302  408-9484919-8929910  06-23-22                       Shipped     Amazon
# 77897  406-8417798-5008349  05-08-22  Shipped - Delivered to Buyer   Merchant
# 16617  406-9325563-2723527  04-20-22                       Shipped     Amazon
# 66899  407-6650964-3555520  05-17-22                       Shipped     Amazon
#
#       Sales Channel  ship-service-level    Style              SKU  \
# index
# 43827      Amazon.in           Standard  JNE3797  JNE3797-KR-XXXL
# 98302      Amazon.in          Expedited    NW029    NW029-ST-SR-L
# 77897      Amazon.in           Standard  JNE3652  JNE3652-TP-N-XL
# 16617      Amazon.in          Expedited    BL021    BL021-71BLACK
# 66899      Amazon.in          Expedited    J0376   J0376-SKD-XXXL
#
#             Category  Size  ... currency  Amount  ship-city ship-state  \
# ...

# %%
df.at[3,"Amount"]
# Out:
# np.float64(753.33)

# %%
df.head(4)
# Out:
#                   Order ID      Date                        Status Fulfilment  \
# index
# 0      405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1      171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2      404-0687676-7273146  04-30-22                       Shipped     Amazon
# 3      403-9615377-8133951  04-30-22                     Cancelled   Merchant
#
#       Sales Channel  ship-service-level    Style              SKU  \
# index
# 0          Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1          Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2          Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3          Amazon.in           Standard    J0341       J0341-DR-L
#
#             Category Size  ... currency  Amount    ship-city   ship-state  \
# index                      ...
# 0                Set    S  ...      INR  647.62       MUMBAI  MAHARASHTRA
# ...

# %%
df.sort_values(["Amount","Category"],ascending=False)
# Out:
#                    Order ID      Date                        Status  \
# index
# 42039   402-5239558-4281957  04-05-22                       Shipped
# 11160   403-4106553-1691525  04-23-22  Shipped - Delivered to Buyer
# 24494   407-3483041-9133135  04-16-22                     Cancelled
# 89150   406-7195963-2374765  05-02-22                       Shipped
# 121225  404-4712917-7300332  06-06-22                       Shipped
# ...                     ...       ...                           ...
# 105300  406-4610317-1624353  06-17-22                     Cancelled
# 107613  171-8009518-6065920  06-15-22                     Cancelled
# 110030  405-7922418-6021961  06-13-22                     Cancelled
# 126738  407-6131601-8283520  06-02-22                     Cancelled
# 127855  171-0571463-7446765  06-01-22                     Cancelled
#
#        Fulfilment Sales Channel  ship-service-level   Style  \
# index
# 42039      Amazon      Amazon.in          Expedited  SET268
# ...
